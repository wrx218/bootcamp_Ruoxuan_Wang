# %% [markdown]
# # Environment & Config Check
#
# Verify that environment variables load correctly and NumPy is available.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
print(f"API_KEY present: {bool(os.getenv('API_KEY'))}")
# Out:
# API_KEY present: True

# %%
import numpy as np

values = np.array([1, 2, 3, 4])
values * 2
# Out:
# array([2, 4, 6, 8])
